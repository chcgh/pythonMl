# %%
import matplotlib.pyplot as plt

# %%
x = [10, 10, 5, 18, 20, 10];
y = [40, 30, 50, 25, 20, 45];
plt.scatter(x, y, c='r', marker='*');
x = [20, 15, 50, 40];
y = [15, 10, 5, 15];
plt.scatter(x, y, c='b', marker='+');
plt.show();
