# %%
import matplotlib.pyplot as plt

# %% [markdown]
# # 1.x和y、x1和y1分开的可视化

# %%
x=[40920,14488,26052,75136,38344,72993,35948,42666,67497,35483]
y=[8.326976,7.153469,1.441871,13.147394,1.669788,10.141740,6.830792,13.276369,8.631577,12.273169]
x1=[25,28,31,35,38,40]
y1=[106,145,167,208,233,258]

# %%
plt.scatter(x1,y1)

# %%
plt.scatter(x,y)

# %% [markdown]
# # 2.x和y、x1和y1合并一张图的可视化

# %% [markdown]
# ## 2.1不同名字一张图片

# %%
x=[40920,14488,26052,75136,38344,72993,35948,42666,67497,35483]
y=[8.326976,7.153469,1.441871,13.147394,1.669788,10.141740,6.830792,13.276369,8.631577,12.273169]
x1=[25,28,31,35,38,40]
y1=[106,145,167,208,233,258]
plt.scatter(x1,y1)
plt.scatter(x,y)

# %% [markdown]
# ## 2.2相同(x,y)名字一张图片

# %%
x=[40920,14488,26052,75136,38344,72993,35948,42666,67497,35483]
y=[8.326976,7.153469,1.441871,13.147394,1.669788,10.141740,6.830792,13.276369,8.631577,12.273169]
plt.scatter(x,y)
x=[25,28,31,35,38,40]
y=[106,145,167,208,233,258]
plt.scatter(x,y)

# %% [markdown]
# # 3、三组x和y在一张图上

# %%
x=[5.1,4.9,4.7,4.6,5.0,5.4]
y=[3.5,3.0,3.2,3.1,3.6,3.9]
plt.scatter(x,y,c='r',marker='*')
x=[7.0,6.4,6.9,5.5,6.5,5.7]
y=[3.2,3.2,3.1,2.3,2.8,2.8]
plt.scatter(x,y,c='b',marker='+')
x=[6.3,5.8,7.1,6.3,6.5,7.6]
y=[3.3,2.7,3.0,2.9,3.0,3.0]
plt.scatter(x,y,c = 'g',marker = 'o') 
# plt.show()
